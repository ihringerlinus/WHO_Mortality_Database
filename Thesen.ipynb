# %% [markdown]
# ## Thesen

# %% [markdown]
# ### These 1: Industrieländer wurden von Covid-19 stärker betroffen als Entwicklungsländer
#
# ### These 2: Karte mit häufigsten Todesursachen pro Land (Europa aufgrund von Datenqulität)
#
# ### These 3: Länder mit höherem BIP haben eine höhere Lebenserwartung vergleich von jeweils 2 Ländern mit unterschiedlichem BIP

# %% [markdown]
# Mittelwert von Ländern Berechnen
